# %% [markdown]
# <a href="https://colab.research.google.com/github/Vinayak989270/TAI-IP/blob/main/Task3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('owid-covid-data.csv')

# %%
df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1          AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 63074      GIN    Africa       Guinea  2020-03-25          4.0        0.0
# 63075      GIN    Africa       Guinea  2020-03-26          4.0        0.0
# 63076      GIN    Africa       Guinea  2020-03-27          8.0        4.0
# 63077      GIN    Africa       Guinea  2020-03-28          8.0        0.0
# 63078      GIN    Africa       Guinea  2020-03-29          1.0        NaN
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                     NaN           NaN         NaN                  NaN  ...
# 1                     NaN           NaN         NaN                  NaN  ...
# 2                     NaN           NaN         NaN                  NaN  ...
# 3                     NaN           NaN         NaN                  NaN  ...
# 4                     NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 63074               0.429           NaN         NaN                  NaN  ...
# 63075               0.429           NaN         NaN                  NaN  ...
# 63076               1.000           NaN         NaN                  NaN  ...
# 63077               0.857           NaN         NaN                  NaN  ...
# 63078                 NaN           NaN         NaN                  NaN  ...
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 0                 NaN           NaN                  37.746
# 1                 NaN           NaN                  37.746
# 2                 NaN           NaN                  37.746
# 3                 NaN           NaN                  37.746
# 4                 NaN           NaN                  37.746
# ...               ...           ...                     ...
# 63074             NaN           NaN                  17.450
# 63075             NaN           NaN                  17.450
# 63076             NaN           NaN                  17.450
# 63077             NaN           NaN                  17.450
# 63078             NaN           NaN                     NaN
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                             0.5            64.83                    0.511
# 1                             0.5            64.83                    0.511
# 2                             0.5            64.83                    0.511
# 3                             0.5            64.83                    0.511
# 4                             0.5            64.83                    0.511
# ...                           ...              ...                      ...
# 63074                         0.3            61.60                    0.477
# 63075                         0.3            61.60                    0.477
# 63076                         0.3            61.60                    0.477
# 63077                         0.3            61.60                    0.477
# 63078                         NaN              NaN                      NaN
#
#        excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                       NaN                          NaN
# 1                                       NaN                          NaN
# 2                                       NaN                          NaN
# 3                                       NaN                          NaN
# 4                                       NaN                          NaN
# ...                                     ...                          ...
# 63074                                   NaN                          NaN
# 63075                                   NaN                          NaN
# 63076                                   NaN                          NaN
# 63077                                   NaN                          NaN
# 63078                                   NaN                          NaN
#
#        excess_mortality  excess_mortality_cumulative_per_million
# 0                   NaN                                      NaN
# 1                   NaN                                      NaN
# 2                   NaN                                      NaN
# 3                   NaN                                      NaN
# 4                   NaN                                      NaN
# ...                 ...                                      ...
# 63074               NaN                                      NaN
# 63075               NaN                                      NaN
# 63076               NaN                                      NaN
# 63077               NaN                                      NaN
# 63078               NaN                                      NaN
#
# [63079 rows x 67 columns]

# %%
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             NaN           NaN                  37.746
# 1             NaN           NaN                  37.746
# 2             NaN           NaN                  37.746
# 3             NaN           NaN                  37.746
# 4             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
#
# [5 rows x 67 columns]

# %%
df.tail()
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 63074      GIN    Africa   Guinea  2020-03-25          4.0        0.0
# 63075      GIN    Africa   Guinea  2020-03-26          4.0        0.0
# 63076      GIN    Africa   Guinea  2020-03-27          8.0        4.0
# 63077      GIN    Africa   Guinea  2020-03-28          8.0        0.0
# 63078      GIN    Africa   Guinea  2020-03-29          1.0        NaN
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 63074               0.429           NaN         NaN                  NaN  ...
# 63075               0.429           NaN         NaN                  NaN  ...
# 63076               1.000           NaN         NaN                  NaN  ...
# 63077               0.857           NaN         NaN                  NaN  ...
# 63078                 NaN           NaN         NaN                  NaN  ...
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 63074             NaN           NaN                   17.45
# 63075             NaN           NaN                   17.45
# 63076             NaN           NaN                   17.45
# 63077             NaN           NaN                   17.45
# 63078             NaN           NaN                     NaN
#
#        hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 63074                         0.3             61.6                    0.477
# 63075                         0.3             61.6                    0.477
# 63076                         0.3             61.6                    0.477
# 63077                         0.3             61.6                    0.477
# 63078                         NaN              NaN                      NaN
#
#        excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 63074                                   NaN                          NaN
# 63075                                   NaN                          NaN
# 63076                                   NaN                          NaN
# 63077                                   NaN                          NaN
# 63078                                   NaN                          NaN
#
#        excess_mortality  excess_mortality_cumulative_per_million
# 63074               NaN                                      NaN
# 63075               NaN                                      NaN
# 63076               NaN                                      NaN
# 63077               NaN                                      NaN
# 63078               NaN                                      NaN
#
# [5 rows x 67 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63079 entries, 0 to 63078
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   iso_code                                    63079 non-null  object
#  1   continent                                   60007 non-null  object
#  2   location                                    63079 non-null  object
#  3   date                                        63079 non-null  object
#  4   total_cases                                 62439 non-null  float64
#  5   new_cases                                   62371 non-null  float64
#  6   new_cases_smoothed                          61599 non-null  float64
#  7   total_deaths                                56040 non-null  float64
#  8   new_deaths                                  56043 non-null  float64
#  9   new_deaths_smoothed                         55217 non-null  float64
#  10  total_cases_per_million                     62438 non-null  float64
#  11  new_cases_per_million                       62371 non-null  float64
#  12  new_cases_smoothed_per_million              61599 non-null  float64
#  13  total_deaths_per_million                    56040 non-null  float64
#  14  new_deaths_per_million                      56043 non-null  float64
#  15  new_deaths_smoothed_per_million             55217 non-null  float64
#  16  reproduction_rate                           46653 non-null  float64
#  17  icu_patients                                10568 non-null  float64
#  18  icu_patients_per_million                    10568 non-null  float64
#  19  hosp_patients                               8662 non-null   float64
#  20  hosp_patients_per_million                   8662 non-null   float64
#  21  weekly_icu_admissions                       2630 non-null   float64
#  22  weekly_icu_admissions_per_million           2630 non-null   float64
#  23  weekly_hosp_admissions                      4680 non-null   float64
#  24  weekly_hosp_admissions_per_million          4680 non-null   float64
#  25  new_tests                                   22659 non-null  float64
#  26  total_tests                                 23545 non-null  float64
#  27  total_tests_per_thousand                    23545 non-null  float64
#  28  new_tests_per_thousand                      22659 non-null  float64
#  29  new_tests_smoothed                          29693 non-null  float64
#  30  new_tests_smoothed_per_thousand             29693 non-null  float64
#  31  positive_rate                               26862 non-null  float64
#  32  tests_per_case                              26710 non-null  float64
#  33  tests_units                                 30705 non-null  object
#  34  total_vaccinations                          16302 non-null  float64
#  35  people_vaccinated                           15416 non-null  float64
#  36  people_fully_vaccinated                     14374 non-null  float64
#  37  total_boosters                              6216 non-null   float64
#  38  new_vaccinations                            13267 non-null  float64
#  39  new_vaccinations_smoothed                   31600 non-null  float64
#  40  total_vaccinations_per_hundred              16302 non-null  float64
#  41  people_vaccinated_per_hundred               15416 non-null  float64
#  42  people_fully_vaccinated_per_hundred         14374 non-null  float64
#  43  total_boosters_per_hundred                  6216 non-null   float64
#  44  new_vaccinations_smoothed_per_million       31600 non-null  float64
#  45  new_people_vaccinated_smoothed              31242 non-null  float64
#  46  new_people_vaccinated_smoothed_per_hundred  31242 non-null  float64
#  47  stringency_index                            49287 non-null  float64
#  48  population                                  63078 non-null  float64
#  49  population_density                          57204 non-null  float64
#  50  median_age                                  51424 non-null  float64
#  51  aged_65_older                               51424 non-null  float64
#  52  aged_70_older                               51424 non-null  float64
#  53  gdp_per_capita                              51409 non-null  float64
#  54  extreme_poverty                             31705 non-null  float64
#  55  cardiovasc_death_rate                       52141 non-null  float64
#  56  diabetes_prevalence                         55740 non-null  float64
#  57  female_smokers                              38398 non-null  float64
#  58  male_smokers                                38398 non-null  float64
#  59  handwashing_facilities                      25472 non-null  float64
#  60  hospital_beds_per_thousand                  46366 non-null  float64
#  61  life_expectancy                             59605 non-null  float64
#  62  human_development_index                     50704 non-null  float64
#  63  excess_mortality_cumulative_absolute        2205 non-null   float64
#  64  excess_mortality_cumulative                 2205 non-null   float64
#  65  excess_mortality                            2205 non-null   float64
#  66  excess_mortality_cumulative_per_million     2205 non-null   float64
# dtypes: float64(62), object(5)
# memory usage: 32.2+ MB

# %%
# Data preprocessing: Convert 'date' column to datetime format
df['date'] = pd.to_datetime(df['date'])

# %%
# Display information about missing values
print("Null Values Before Cleaning:")
print(df.isnull().sum())

# Dropping rows with null values
data_cleaned = df.dropna()
# Out:
# Null Values Before Cleaning:
# iso_code                                       0
# continent                                   3072
# location                                       0
# date                                           0
# total_cases                                  640
#                                            ...
# human_development_index                    12375
# excess_mortality_cumulative_absolute       60874
# excess_mortality_cumulative                60874
# excess_mortality                           60874
# excess_mortality_cumulative_per_million    60874
# Length: 67, dtype: int64

# %%
# Group by date and sum the new cases for each day
daily_cases = df.groupby('date')['new_cases'].sum().reset_index()

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(daily_cases['date'], daily_cases['new_cases'], marker='o', linestyle='-')
plt.title('Daily New COVID-19 Cases')
plt.xlabel('Date')
plt.ylabel('Number of Cases')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Group by date and sum the new deaths for each day
daily_deaths = df.groupby('date')['new_deaths'].sum().reset_index()

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(daily_deaths['date'], daily_deaths['new_deaths'], marker='o', linestyle='-')
plt.title('Daily COVID-19 Deaths')
plt.xlabel('Date')
plt.ylabel('Number of Deaths')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Calculate daily recoveries
df['daily_recoveries'] = df['total_cases'] - df['total_deaths']

# Group by date and calculate the sum of daily recoveries for each day
daily_recoveries = df.groupby('date')['daily_recoveries'].sum().reset_index()

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(daily_recoveries['date'], daily_recoveries['daily_recoveries'], marker='o', linestyle='-')
plt.title('Daily COVID-19 Recoveries (Estimated)')
plt.xlabel('Date')
plt.ylabel('Number of Recoveries')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
columns_of_interest = ['date', 'location', 'total_cases', 'new_cases', 'total_vaccinations', 'people_vaccinated', 'people_fully_vaccinated']
selected_data = df[columns_of_interest]

# Filter data for a specific country or region
country_data = selected_data[selected_data['location'] == 'India']

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(country_data['date'], country_data['total_cases'], label='Total Cases', color='blue')
plt.plot(country_data['date'], country_data['new_cases'], label='Daily Cases', color='orange')
plt.plot(country_data['date'], country_data['total_vaccinations'], label='Total Vaccinations', color='green')
plt.plot(country_data['date'], country_data['people_vaccinated'], label='People Vaccinated', color='purple')
plt.plot(country_data['date'], country_data['people_fully_vaccinated'], label='People Fully Vaccinated', color='red')

plt.title('Impact of Vaccination on COVID-19 Infection Rates for selected location')
plt.xlabel('Date')
plt.ylabel('Count')
plt.legend()
plt.grid(True)
plt.show()
